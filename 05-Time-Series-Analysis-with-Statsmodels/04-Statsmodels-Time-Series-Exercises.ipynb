# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Statsmodels Time Series Excercises
# For this set of exercises we're using data from the Federal Reserve Economic Database (FRED) concerning the Industrial Production Index for Electricity and Gas Utilities from January 1970 to December 1989.
#
# Data source: https://fred.stlouisfed.org/series/IPG2211A2N
#
# <div class="alert alert-danger" style="margin: 10px"><strong>IMPORTANT NOTE!</strong> Make sure you don't run the cells directly above the example output shown, <br>otherwise you will end up writing over the example output!</div>

# %%
# RUN THIS CELL
import pandas as pd
import numpy as np
# %matplotlib inline

df = pd.read_csv('../Data/EnergyProduction.csv',index_col=0,parse_dates=True)
df.head()
# Out:
#             EnergyIndex
# DATE
# 1970-01-01      43.0869
# 1970-02-01      42.5577
# 1970-03-01      41.6215
# 1970-04-01      40.1982
# 1970-05-01      39.9321

# %%
df.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-02-01', '1970-03-01', '1970-04-01',
#                '1970-05-01', '1970-06-01', '1970-07-01', '1970-08-01',
#                '1970-09-01', '1970-10-01',
#                ...
#                '1989-03-01', '1989-04-01', '1989-05-01', '1989-06-01',
#                '1989-07-01', '1989-08-01', '1989-09-01', '1989-10-01',
#                '1989-11-01', '1989-12-01'],
#               dtype='datetime64[ns]', name='DATE', length=240, freq=None)

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of             EnergyIndex
# DATE
# 1970-01-01      43.0869
# 1970-02-01      42.5577
# 1970-03-01      41.6215
# 1970-04-01      40.1982
# 1970-05-01      39.9321
# 1970-06-01      41.1847
# 1970-07-01      43.2230
# 1970-08-01      44.8138
# 1970-09-01      43.6007
# 1970-10-01      40.5467
# 1970-11-01      40.9385
# 1970-12-01      42.1117
# 1971-01-01      44.9517
# 1971-02-01      44.3696
# 1971-03-01      42.7548
# 1971-04-01      41.4234
# 1971-05-01      40.8295
# 1971-06-01      43.5488
# 1971-07-01      45.1876
# 1971-08-01      46.1091
# 1971-09-01      45.5050
# 1971-10-01      43.9496
# 1971-11-01      44.0030
# 1971-12-01      45.6054
# 1972-01-01      48.8392
# 1972-02-01      50.0191
# 1972-03-01      47.8421
# 1972-04-01      44.5127
# 1972-05-01      42.1061
# 1972-06-01      43.8217
# ...                 ...
# 1987-07-01      69.0282
# 1987-08-01      70.2369
# 1987-09-01      64.2987
# 1987-10-01      60.5402
# 1987-11-01      62.6219
# 1987-12-01      70.7671
# 1988-01-01      80.0833
# 1988-02-01      76.3631
# 1988-03-01      70.4954
# 1988-04-01      63.4244
# 1988-05-01      61.5776
# 1988-06-01      67.2741
# 1988-07-01      73.1676
# 1988-08-01      75.9479
# 1988-09-01      67.7223
# 1988-10-01      63.4592
# 1988-11-01      65.2706
# 1988-12-01      74.0492
# 1989-01-01      78.1368
# 1989-02-01      76.8499
# 1989-03-01      73.5377
# 1989-04-01      65.2676
# 1989-05-01      63.8617
# 1989-06-01      68.6587
# 1989-07-01      74.2491
# 1989-08-01      75.2704
# 1989-09-01      69.5107
# 1989-10-01      66.0620
# 1989-11-01      69.2555
# 1989-12-01      84.4040
#
# [240 rows x 1 columns]>

# %% [markdown]
# ### 1. Assign a frequency of 'MS' to the DatetimeIndex.

# %%
# CODE HERE
df.index.freq = 'MS'
df.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-02-01', '1970-03-01', '1970-04-01',
#                '1970-05-01', '1970-06-01', '1970-07-01', '1970-08-01',
#                '1970-09-01', '1970-10-01',
#                ...
#                '1989-03-01', '1989-04-01', '1989-05-01', '1989-06-01',
#                '1989-07-01', '1989-08-01', '1989-09-01', '1989-10-01',
#                '1989-11-01', '1989-12-01'],
#               dtype='datetime64[ns]', name='DATE', length=240, freq='MS')

# %%
# DON'T WRITE HERE
# Out:
# DatetimeIndex(['1970-01-01', '1970-02-01', '1970-03-01', '1970-04-01',
#                '1970-05-01', '1970-06-01', '1970-07-01', '1970-08-01',
#                '1970-09-01', '1970-10-01',
#                ...
#                '1989-03-01', '1989-04-01', '1989-05-01', '1989-06-01',
#                '1989-07-01', '1989-08-01', '1989-09-01', '1989-10-01',
#                '1989-11-01', '1989-12-01'],
#               dtype='datetime64[ns]', name='DATE', length=240, freq='MS')

# %% [markdown]
# ### 2. Plot the dataset.

# %%
# CODE HERE
df.plot(figsize=(10,5))

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 3. Add a column that shows a 12-month Simple Moving Average (SMA).<br>&nbsp;&nbsp;&nbsp;&nbsp;Plot the result.

# %%
df['SMA12']= df['EnergyIndex'].rolling(window=12).mean()

# %%
df.head(20)
# Out:
#             EnergyIndex      SMA12      SES12
# DATE
# 1970-01-01      43.0869        NaN  43.086900
# 1970-02-01      42.5577        NaN  43.005485
# 1970-03-01      41.6215        NaN  42.792564
# 1970-04-01      40.1982        NaN  42.393431
# 1970-05-01      39.9321        NaN  42.014765
# 1970-06-01      41.1847        NaN  41.887062
# 1970-07-01      43.2230        NaN  42.092591
# 1970-08-01      44.8138        NaN  42.511239
# 1970-09-01      43.6007        NaN  42.678848
# 1970-10-01      40.5467        NaN  42.350825
# 1970-11-01      40.9385        NaN  42.133545
# 1970-12-01      42.1117  41.984625  42.130184
# 1971-01-01      44.9517  42.140025  42.564263
# 1971-02-01      44.3696  42.291017  42.842007
# 1971-03-01      42.7548  42.385458  42.828591
# 1971-04-01      41.4234  42.487558  42.612408
# 1971-05-01      40.8295  42.562342  42.338114
# 1971-06-01      43.5488  42.759350  42.524374
# 1971-07-01      45.1876  42.923067  42.934101
# 1971-08-01      46.1091  43.031008  43.422562

# %%
df.plot(figsize=(10,5))

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 4. Add a column that shows an Exponentially Weighted Moving Average (EWMA) with a span of 12 using the statsmodels <tt>SimpleExpSmoothing</tt> function. Plot the result.

# %%
# DON'T FORGET TO PERFORM THE IMPORT!

from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
span=12
alpha = 2/(span+1)

# %%
model = SimpleExpSmoothing(df['EnergyIndex'])

# %%
fitted_model = model.fit(smoothing_level=alpha,optimized=False)

# %%
df['SES12'] = fitted_model.fittedvalues.shift(-1)

# %%
df.head()
# Out:
#             EnergyIndex  SMA12      SES12
# DATE
# 1970-01-01      43.0869    NaN  43.086900
# 1970-02-01      42.5577    NaN  43.005485
# 1970-03-01      41.6215    NaN  42.792564
# 1970-04-01      40.1982    NaN  42.393431
# 1970-05-01      39.9321    NaN  42.014765

# %%
df.plot(figsize=(10,5))

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### 5. Add a column to the DataFrame that shows a Holt-Winters fitted model using Triple Exponential Smoothing with multiplicative models. Plot the result.

# %%
# DON'T FORGET TO PERFORM THE IMPORT!

from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
span = 12
aplpha = 2/(span+1)

# %%
model = ExponentialSmoothing(df['EnergyIndex'],trend='add',seasonal= 'add',seasonal_periods=12)

# %%
fitted_model = model.fit()

# %%
df['TESADD12'] =fitted_model.fittedvalues

# %%
#df.drop('TESMUL12',axis=1,inplace=True)

# %%
#one liner does the same as above
#df['TES12'] = ExponentialSmoothing(df['EnergyIndex'],trend='add',seasonal='add',seasonal_periods=12).fit().fittedvalues

# %%
df.head()
# Out:
#             EnergyIndex  SMA12      SES12   TESADD12
# DATE
# 1970-01-01      43.0869    NaN  43.086900  43.277146
# 1970-02-01      42.5577    NaN  43.005485  41.795038
# 1970-03-01      41.6215    NaN  42.792564  40.062873
# 1970-04-01      40.1982    NaN  42.393431  38.739594
# 1970-05-01      39.9321    NaN  42.014765  38.955755

# %%
df.plot(figsize=(10,4))

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### OPTIONAL: Plot the same  as above, but for only the first two years.

# %%
df.iloc[:24].plot(figsize=(10,5))

# %%
# DON'T WRITE HERE

# %% [markdown]
# ### BONUS QUESTION: There is a visible decline in the Industrial Production Index around 1982-1983.<br>Why do you think this might be?

# %%
# due to the recesion in the US in this period

# %% [markdown]
# ## Great job!
